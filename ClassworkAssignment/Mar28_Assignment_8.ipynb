# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
from keras.regularizers import l1_l2
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-03-26 19:37:01.628767: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-26 19:37:01.628885: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/10
# 2023-03-26 19:37:02.192107: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-26 19:37:02.425239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 391/391 [==============================] - ETA: 0s - loss: 217.5461 - accuracy: 0.2281
# 2023-03-26 19:38:15.036592: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 391/391 [==============================] - 79s 196ms/step - loss: 217.5461 - accuracy: 0.2281 - val_loss: 10.5665 - val_accuracy: 0.2936
# Epoch 2/10
# Epoch 2/10
# 391/391 [==============================] - 77s 196ms/step - loss: 10.8526 - accuracy: 0.3031 - val_loss: 9.9557 - val_accuracy: 0.3383
# Epoch 3/10
# 391/391 [==============================] - 76s 195ms/step - loss: 9.8797 - accuracy: 0.3636 - val_loss: 21.7030 - val_accuracy: 0.3872
# Epoch 4/10
# 391/391 [==============================] - 76s 195ms/step - loss: 9.5146 - accuracy: 0.3928 - val_loss: 9.2541 - val_accuracy: 0.4158
# Epoch 5/10
# 391/391 [==============================] - 76s 194ms/step - loss: 9.4194 - accuracy: 0.4187 - val_loss: 22.2277 - val_accuracy: 0.4257
# Epoch 6/10
# 391/391 [==============================] - 76s 193ms/step - loss: 9.4986 - accuracy: 0.4317 - val_loss: 25.2358 - val_accuracy: 0.4438
# Epoch 7/10
# 391/391 [==============================] - 76s 194ms/step - loss: 9.6548 - accuracy: 0.4396 - val_loss: 24.0985 - val_accuracy: 0.4343
# Epoch 8/10
# 391/391 [==============================] - 76s 195ms/step - loss: 9.4692 - accuracy: 0.4496 - val_loss: 24.1201 - val_accuracy: 0.4480
# Epoch 9/10
# 391/391 [==============================] - 76s 194ms/step - loss: 9.0169 - accuracy: 0.4568 - val_loss: 8.8884 - val_accuracy: 0.4618
# Epoch 10/10
# 391/391 [==============================] - 76s 194ms/step - loss: 9.3384 - accuracy: 0.4650 - val_loss: 31.5224 - val_accuracy: 0.4728
# 313/313 [==============================] - 14s 44ms/step - loss: 30.0564 - accuracy: 0.4728
# Loss: 30.056
# Accuracy: 0.473

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
from keras.constraints import max_norm
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', kernel_costraint=max_norm(3.)))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment in line 215
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=212'>213</a> # Classifier inclusion
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=213'>214</a> model.add(Flatten())
# --> <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=214'>215</a> model.add(Dense(1024, activation='relu', kernel_costraint=max_norm(3.)))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=215'>216</a> model.add(Dense(10, activation='softmax'))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=216'>217</a> # Compiling the model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py:95, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=91'>92</a>     if layout:
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=92'>93</a>       layout_args[variable_name + "_layout"] = layout
# ---> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=94'>95</a> init_method(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=96'>97</a> # Inject the layout parameter after the invocation of __init__()
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=97'>98</a> for layout_param_name, layout in layout_args.items():
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py:113, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=99'>100</a> @utils.allow_initializer_layout
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=100'>101</a> def __init__(self,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=101'>102</a>              units,
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=110'>111</a>              bias_constraint=None,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=111'>112</a>              **kwargs):
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=112'>113</a>   super(Dense, self).__init__(
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=113'>114</a>       activity_regularizer=activity_regularizer, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=115'>116</a>   self.units = int(units) if not isinstance(units, int) else units
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=116'>117</a>   if self.units < 0:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=584'>585</a> self._self_setattr_tracking = False  # pylint: disable=protected-access
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=585'>586</a> try:
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=586'>587</a>   result = method(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=587'>588</a> finally:
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=588'>589</a>   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py:332, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=320'>321</a> allowed_kwargs = {
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=321'>322</a>     'input_dim',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=322'>323</a>     'input_shape',
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=328'>329</a>     'implementation',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=329'>330</a> }
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=330'>331</a> # Validate optional keyword arguments.
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=331'>332</a> generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=333'>334</a> # Mutable properties
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=334'>335</a> # Indicates whether the layer's weights are updated during training
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=335'>336</a> # and whether the layer's updates are run during training.
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=336'>337</a> if not (isinstance(trainable, bool) or
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=337'>338</a>         (isinstance(trainable, (tf.Tensor, tf.Variable)) and
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=338'>339</a>          trainable.dtype is tf.bool)):
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py:1174, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1171'>1172</a> for kwarg in kwargs:
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1172'>1173</a>   if kwarg not in allowed_kwargs:
# -> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1173'>1174</a>     raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'kernel_costraint')

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
from keras.constraints import max_norm
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', 
                kernel_costraint=max_norm(3.)))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment in line 215
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=212'>213</a> # Classifier inclusion
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=213'>214</a> model.add(Flatten())
# --> <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=214'>215</a> model.add(Dense(1024, activation='relu',
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=215'>216</a>                 kernel_costraint=max_norm(3.)))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=216'>217</a> model.add(Dense(10, activation='softmax'))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=217'>218</a> # Compiling the model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py:95, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=91'>92</a>     if layout:
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=92'>93</a>       layout_args[variable_name + "_layout"] = layout
# ---> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=94'>95</a> init_method(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=96'>97</a> # Inject the layout parameter after the invocation of __init__()
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=97'>98</a> for layout_param_name, layout in layout_args.items():
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py:113, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=99'>100</a> @utils.allow_initializer_layout
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=100'>101</a> def __init__(self,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=101'>102</a>              units,
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=110'>111</a>              bias_constraint=None,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=111'>112</a>              **kwargs):
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=112'>113</a>   super(Dense, self).__init__(
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=113'>114</a>       activity_regularizer=activity_regularizer, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=115'>116</a>   self.units = int(units) if not isinstance(units, int) else units
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=116'>117</a>   if self.units < 0:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=584'>585</a> self._self_setattr_tracking = False  # pylint: disable=protected-access
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=585'>586</a> try:
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=586'>587</a>   result = method(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=587'>588</a> finally:
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=588'>589</a>   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py:332, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=320'>321</a> allowed_kwargs = {
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=321'>322</a>     'input_dim',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=322'>323</a>     'input_shape',
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=328'>329</a>     'implementation',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=329'>330</a> }
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=330'>331</a> # Validate optional keyword arguments.
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=331'>332</a> generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=333'>334</a> # Mutable properties
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=334'>335</a> # Indicates whether the layer's weights are updated during training
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=335'>336</a> # and whether the layer's updates are run during training.
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=336'>337</a> if not (isinstance(trainable, bool) or
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=337'>338</a>         (isinstance(trainable, (tf.Tensor, tf.Variable)) and
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=338'>339</a>          trainable.dtype is tf.bool)):
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py:1174, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1171'>1172</a> for kwarg in kwargs:
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1172'>1173</a>   if kwarg not in allowed_kwargs:
# -> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1173'>1174</a>     raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'kernel_costraint')

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
from keras.constraints import max_norm
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', 
                kernel_costraint=max_norm(3)))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment in line 215
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=212'>213</a> # Classifier inclusion
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=213'>214</a> model.add(Flatten())
# --> <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=214'>215</a> model.add(Dense(1024, activation='relu',
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=215'>216</a>                 kernel_costraint=max_norm(3)))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=216'>217</a> model.add(Dense(10, activation='softmax'))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=217'>218</a> # Compiling the model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py:95, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=91'>92</a>     if layout:
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=92'>93</a>       layout_args[variable_name + "_layout"] = layout
# ---> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=94'>95</a> init_method(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=96'>97</a> # Inject the layout parameter after the invocation of __init__()
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=97'>98</a> for layout_param_name, layout in layout_args.items():
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py:113, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=99'>100</a> @utils.allow_initializer_layout
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=100'>101</a> def __init__(self,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=101'>102</a>              units,
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=110'>111</a>              bias_constraint=None,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=111'>112</a>              **kwargs):
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=112'>113</a>   super(Dense, self).__init__(
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=113'>114</a>       activity_regularizer=activity_regularizer, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=115'>116</a>   self.units = int(units) if not isinstance(units, int) else units
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=116'>117</a>   if self.units < 0:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=584'>585</a> self._self_setattr_tracking = False  # pylint: disable=protected-access
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=585'>586</a> try:
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=586'>587</a>   result = method(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=587'>588</a> finally:
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=588'>589</a>   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py:332, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=320'>321</a> allowed_kwargs = {
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=321'>322</a>     'input_dim',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=322'>323</a>     'input_shape',
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=328'>329</a>     'implementation',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=329'>330</a> }
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=330'>331</a> # Validate optional keyword arguments.
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=331'>332</a> generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=333'>334</a> # Mutable properties
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=334'>335</a> # Indicates whether the layer's weights are updated during training
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=335'>336</a> # and whether the layer's updates are run during training.
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=336'>337</a> if not (isinstance(trainable, bool) or
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=337'>338</a>         (isinstance(trainable, (tf.Tensor, tf.Variable)) and
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=338'>339</a>          trainable.dtype is tf.bool)):
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py:1174, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1171'>1172</a> for kwarg in kwargs:
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1172'>1173</a>   if kwarg not in allowed_kwargs:
# -> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1173'>1174</a>     raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'kernel_costraint')

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
from keras.constraints import max_norm
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', 
                kernel_costraint=max_norm(3.)))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment in line 215
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=212'>213</a> # Classifier inclusion
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=213'>214</a> model.add(Flatten())
# --> <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=214'>215</a> model.add(Dense(1024, activation='relu',
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=215'>216</a>                 kernel_costraint=max_norm(3.)))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=216'>217</a> model.add(Dense(10, activation='softmax'))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=217'>218</a> # Compiling the model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py:95, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=91'>92</a>     if layout:
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=92'>93</a>       layout_args[variable_name + "_layout"] = layout
# ---> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=94'>95</a> init_method(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=96'>97</a> # Inject the layout parameter after the invocation of __init__()
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=97'>98</a> for layout_param_name, layout in layout_args.items():
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py:113, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=99'>100</a> @utils.allow_initializer_layout
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=100'>101</a> def __init__(self,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=101'>102</a>              units,
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=110'>111</a>              bias_constraint=None,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=111'>112</a>              **kwargs):
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=112'>113</a>   super(Dense, self).__init__(
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=113'>114</a>       activity_regularizer=activity_regularizer, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=115'>116</a>   self.units = int(units) if not isinstance(units, int) else units
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=116'>117</a>   if self.units < 0:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=584'>585</a> self._self_setattr_tracking = False  # pylint: disable=protected-access
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=585'>586</a> try:
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=586'>587</a>   result = method(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=587'>588</a> finally:
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=588'>589</a>   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py:332, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=320'>321</a> allowed_kwargs = {
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=321'>322</a>     'input_dim',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=322'>323</a>     'input_shape',
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=328'>329</a>     'implementation',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=329'>330</a> }
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=330'>331</a> # Validate optional keyword arguments.
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=331'>332</a> generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=333'>334</a> # Mutable properties
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=334'>335</a> # Indicates whether the layer's weights are updated during training
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=335'>336</a> # and whether the layer's updates are run during training.
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=336'>337</a> if not (isinstance(trainable, bool) or
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=337'>338</a>         (isinstance(trainable, (tf.Tensor, tf.Variable)) and
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=338'>339</a>          trainable.dtype is tf.bool)):
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py:1174, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1171'>1172</a> for kwarg in kwargs:
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1172'>1173</a>   if kwarg not in allowed_kwargs:
# -> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1173'>1174</a>     raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'kernel_costraint')

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
from keras.constraints import max_norm
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', 
                kernel_costraint=max_norm(.3)))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment in line 215
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=212'>213</a> # Classifier inclusion
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=213'>214</a> model.add(Flatten())
# --> <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=214'>215</a> model.add(Dense(1024, activation='relu',
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=215'>216</a>                 kernel_costraint=max_norm(.3)))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=216'>217</a> model.add(Dense(10, activation='softmax'))
#     <a href='file:///Users/dcmac14/Documents/GitHub/Machine-Learning-2023/Textbook/Mar28_Assignment?line=217'>218</a> # Compiling the model
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py:95, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=91'>92</a>     if layout:
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=92'>93</a>       layout_args[variable_name + "_layout"] = layout
# ---> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=94'>95</a> init_method(layer_instance, *args, **kwargs)
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=96'>97</a> # Inject the layout parameter after the invocation of __init__()
#      <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/dtensor/utils.py?line=97'>98</a> for layout_param_name, layout in layout_args.items():
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py:113, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=99'>100</a> @utils.allow_initializer_layout
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=100'>101</a> def __init__(self,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=101'>102</a>              units,
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=110'>111</a>              bias_constraint=None,
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=111'>112</a>              **kwargs):
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=112'>113</a>   super(Dense, self).__init__(
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=113'>114</a>       activity_regularizer=activity_regularizer, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=115'>116</a>   self.units = int(units) if not isinstance(units, int) else units
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/layers/core/dense.py?line=116'>117</a>   if self.units < 0:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=584'>585</a> self._self_setattr_tracking = False  # pylint: disable=protected-access
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=585'>586</a> try:
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=586'>587</a>   result = method(self, *args, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=587'>588</a> finally:
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/tracking/base.py?line=588'>589</a>   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py:332, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=320'>321</a> allowed_kwargs = {
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=321'>322</a>     'input_dim',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=322'>323</a>     'input_shape',
#    (...)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=328'>329</a>     'implementation',
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=329'>330</a> }
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=330'>331</a> # Validate optional keyword arguments.
# --> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=331'>332</a> generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=333'>334</a> # Mutable properties
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=334'>335</a> # Indicates whether the layer's weights are updated during training
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=335'>336</a> # and whether the layer's updates are run during training.
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=336'>337</a> if not (isinstance(trainable, bool) or
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=337'>338</a>         (isinstance(trainable, (tf.Tensor, tf.Variable)) and
#     <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/engine/base_layer.py?line=338'>339</a>          trainable.dtype is tf.bool)):
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py:1174, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1171'>1172</a> for kwarg in kwargs:
#    <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1172'>1173</a>   if kwarg not in allowed_kwargs:
# -> <a href='file:///Users/dcmac14/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/generic_utils.py?line=1173'>1174</a>     raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'kernel_costraint')

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.constraints import max_norm
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', 
 #               kernel_costraint=max_norm(3.)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

# Dropout
# Dropout layer import
from keras.layers import Dropout
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Dropout(0.25))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.25))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.25))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# Epoch 1/10
# 2023-03-27 12:01:34.284919: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 391/391 [==============================] - ETA: 0s - loss: 1.5885 - accuracy: 0.4274
# 2023-03-27 12:02:35.906428: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 391/391 [==============================] - 67s 166ms/step - loss: 1.5885 - accuracy: 0.4274 - val_loss: 1.2723 - val_accuracy: 0.5486
# Epoch 2/10
# Epoch 2/10
# 391/391 [==============================] - 64s 164ms/step - loss: 1.1836 - accuracy: 0.5842 - val_loss: 1.0480 - val_accuracy: 0.6347
# Epoch 3/10
# 391/391 [==============================] - 64s 163ms/step - loss: 0.9897 - accuracy: 0.6559 - val_loss: 0.9532 - val_accuracy: 0.6691
# Epoch 4/10
# 391/391 [==============================] - 64s 163ms/step - loss: 0.8489 - accuracy: 0.7038 - val_loss: 0.8969 - val_accuracy: 0.6893
# Epoch 5/10
# 391/391 [==============================] - 64s 163ms/step - loss: 0.7297 - accuracy: 0.7497 - val_loss: 0.8630 - val_accuracy: 0.7040
# Epoch 6/10
# 391/391 [==============================] - 64s 165ms/step - loss: 0.6179 - accuracy: 0.7869 - val_loss: 0.8783 - val_accuracy: 0.6978
# Epoch 7/10
# 391/391 [==============================] - 65s 166ms/step - loss: 0.5179 - accuracy: 0.8231 - val_loss: 0.8329 - val_accuracy: 0.7222
# Epoch 8/10
# 391/391 [==============================] - 64s 164ms/step - loss: 0.4190 - accuracy: 0.8548 - val_loss: 0.8500 - val_accuracy: 0.7215
# Epoch 9/10
# 391/391 [==============================] - 64s 164ms/step - loss: 0.3276 - accuracy: 0.8887 - val_loss: 0.8894 - val_accuracy: 0.7204
# Epoch 10/10
# 391/391 [==============================] - 64s 164ms/step - loss: 0.2551 - accuracy: 0.9138 - val_loss: 0.9252 - val_accuracy: 0.7242
# 313/313 [==============================] - 10s 31ms/step - loss: 0.9252 - accuracy: 0.7242
# Loss: 0.925
# Accuracy: 0.724

# %%
# Load of necessary libraries
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import to_categorical
# to make the example replicable
np.random.seed(42)
# Load of the dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()


import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(len(class_names)):
  ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
  idx = np.where(Y_train[:]==i)[0]
  features_idx = X_train[idx,::]
  img_num = np.random.randint(features_idx.shape[0])
  im = features_idx[img_num,::]
  ax.set_title(class_names[i])
  #im = np.transpose(features_idx[img_num,::], (1, 2, 0))
  plt.imshow(im)
plt.show()


# Cenetering the data
X_train_mean = np.mean(X_train, axis = 0)
X_train_cent = X_train - X_train_mean
# Normalization
X_train_std = np.std(X_train, axis = 0)
X_train_norm = X_train_cent / X_train_std

#test split
X_test_norm = (X_test - X_train_mean) / X_train_std

#_1
# Initializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# We add our classificator
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training of the model
#model.fit(X_train, to_categorical(Y_train),
   #       batch_size=128,
    #      shuffle=True,
     #     epochs=10,
      #    validation_data=(X_test, to_categorical(Y_test)))
# Evaluation of the model
#scores = model.evaluate(X_test, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_2
# We Import Batch Normalizarion layer
#from keras.layers import BatchNormalization, Activation
# Inizializting the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(32, 32, 3)))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# Defining a thirdd convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))
# We include our classifier
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Training the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test))) # aquí deberíamos usar un conjunto distinto al de test!!!
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])


#_3
# L2 Regularization
# Regularizer layer import
#from keras.regularizers import l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_4 
# L1 Regularization
# Regularizer layer import
#from keras.regularizers import l1
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1(0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_5 L1 + L2
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.regularizers import l1_l2
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', kernel_regularizer=l1_l2(0.01, 0.01)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_6 
# Elastic Net Regularization (L1 + L2)
# Regularizer layer import
#from keras.constraints import max_norm
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu', 
 #               kernel_costraint=max_norm(3.)))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])

#_7
# Dropout
# Dropout layer import
#from keras.layers import Dropout
# Inizializing the model
#model = Sequential()
# Defining a convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
#model.add(Dropout(0.25))
# Defining a second convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(Dropout(0.25))
# Defining a third convolutional layer
#model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
#model.add(Dropout(0.25))
# Classifier inclusion
#model.add(Flatten())
#model.add(Dense(1024, activation='relu'))
#model.add(Dropout(0.5))
#model.add(Dense(10, activation='softmax'))
# Compiling the model
#model.compile(loss='categorical_crossentropy',
 #             optimizer=Adam(lr=0.0001, decay=1e-6),
  #            metrics=['accuracy'])
# Traning the model
#model.fit(X_train_norm, to_categorical(Y_train),
 #         batch_size=128,
  #        shuffle=True,
   #       epochs=10,
    #      validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
#scores = model.evaluate(X_test_norm, to_categorical(Y_test))
#print('Loss: %.3f' % scores[0])
#print('Accuracy: %.3f' % scores[1])



#_8
# Dropout & Max Norm
# Dropout & Max Norm layers import
from keras.layers import Dropout
from keras.constraints import max_norm
# Inizializing the model
model = Sequential()
# Defining a convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Dropout(0.25))
# Defining a second convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.25))
# Defining a third convolutional layer
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.25))
# Classifier inclusion
model.add(Flatten())
model.add(Dense(1024, activation='relu', kernel_constraint=max_norm(3.)))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=['accuracy'])
# Traning the model
model.fit(X_train_norm, to_categorical(Y_train),
          batch_size=128,
          shuffle=True,
          epochs=10,
          validation_data=(X_test_norm, to_categorical(Y_test)))
# Evaluating the model
scores = model.evaluate(X_test_norm, to_categorical(Y_test))
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# Epoch 1/10
# 2023-03-27 12:14:01.187037: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 391/391 [==============================] - ETA: 0s - loss: 1.5959 - accuracy: 0.4256
# 2023-03-27 12:15:06.605012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 391/391 [==============================] - 71s 176ms/step - loss: 1.5959 - accuracy: 0.4256 - val_loss: 1.3009 - val_accuracy: 0.5424
# Epoch 2/10
# Epoch 2/10
# 391/391 [==============================] - 68s 173ms/step - loss: 1.1913 - accuracy: 0.5797 - val_loss: 1.0497 - val_accuracy: 0.6255
# Epoch 3/10
# 391/391 [==============================] - 67s 172ms/step - loss: 0.9967 - accuracy: 0.6524 - val_loss: 0.9610 - val_accuracy: 0.6640
# Epoch 4/10
# 391/391 [==============================] - 68s 174ms/step - loss: 0.8661 - accuracy: 0.6993 - val_loss: 0.9066 - val_accuracy: 0.6861
# Epoch 5/10
# 391/391 [==============================] - 68s 173ms/step - loss: 0.7571 - accuracy: 0.7369 - val_loss: 0.8686 - val_accuracy: 0.7013
# Epoch 6/10
# 391/391 [==============================] - 68s 173ms/step - loss: 0.6507 - accuracy: 0.7742 - val_loss: 0.8355 - val_accuracy: 0.7108
# Epoch 7/10
# 391/391 [==============================] - 68s 174ms/step - loss: 0.5479 - accuracy: 0.8107 - val_loss: 0.8352 - val_accuracy: 0.7190
# Epoch 8/10
# 391/391 [==============================] - 68s 173ms/step - loss: 0.4579 - accuracy: 0.8425 - val_loss: 0.8498 - val_accuracy: 0.7190
# Epoch 9/10
# 391/391 [==============================] - 68s 173ms/step - loss: 0.3701 - accuracy: 0.8746 - val_loss: 0.8590 - val_accuracy: 0.7248
# Epoch 10/10
# 391/391 [==============================] - 68s 173ms/step - loss: 0.2953 - accuracy: 0.8998 - val_loss: 0.8874 - val_accuracy: 0.7212
# 313/313 [==============================] - 10s 31ms/step - loss: 0.8874 - accuracy: 0.7212
# Loss: 0.887
# Accuracy: 0.721
